# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from faker.providers.credit_card import Provider as CreditCardProvider
import datetime

# %%
url = "https://raw.githubusercontent.com/umaimehm/Intro_to_AI_2021/main/assignment1/Ruter_data.csv"
df = pd.read_csv(url, sep=";")
df.head()
# Out:
#                              TurId        Dato  Fylke Område Kommune  \
# 0  15006-2020-08-10T10:24:00+02:00  10/08/2020  Viken   Vest   Bærum
# 1  15002-2020-08-15T12:54:00+02:00  15/08/2020  Viken   Vest   Bærum
# 2  15004-2020-08-03T09:54:00+02:00  03/08/2020  Viken   Vest   Bærum
# 3  15003-2020-07-27T13:00:00+02:00  27/07/2020  Viken   Vest   Bærum
# 4  15002-2020-08-27T07:15:00+02:00  27/08/2020  Viken   Vest   Bærum
#
#                   Holdeplass_Fra                        Holdeplass_Til  \
# 0                    Nordliveien                             Tjernsmyr
# 1               Nadderud stadion  Bekkestua bussterminal (Plattform C)
# 2               Ringstabekkveien                               Skallum
# 3                      Gruvemyra                              Gullhaug
# 4  Lysaker stasjon (Plattform A)                             Tjernsmyr
#
#   Linjetype Linjefylke Linjenavn  Linjeretning  \
# 0     Lokal      Viken       150             0
# 1     Lokal      Viken       150             0
# 2     Lokal      Viken       150             0
# 3     Lokal      Viken       150             1
# 4     Lokal      Viken       150             1
#
#   Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# 0                                 10:53:53
# 1                                 13:12:20
# 2                                 10:18:56
# 3                                 13:52:04
# 4                                 07:34:13
#
#   Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# 0                                10:53:59
# 1                                13:12:26
# 2                                10:19:21
# 3                                13:52:26
# 4                                07:34:53
#
#   Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# 0                                  10:53:00
# 1                                  13:12:00
# 2                                  10:19:00
# 3                                  13:51:00
# 4                                  07:33:00
#
#   Tidspunkt_Planlagt_Avgang_Holdeplass_Fra  Kjøretøy_Kapasitet  \
# 0                                 10:53:00                 112
# 1                                 13:12:00                 112
# 2                                 10:19:00                 112
# 3                                 13:51:00                 112
# 4                                 07:33:00                 112
#
#    Passasjerer_Ombord
# 0                   5
# 1                   5
# 2                   6
# 3                  10
# 4                  10

# %% [markdown]
# ### Task 1.1
# **Identify 5 unique features from this data set**

# %% [markdown]
# 1.
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# #### Clean and convert

# %% [markdown]
# Fjerner ugyldig tid

# %%
df = df[df['Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra'] < '24:00:00']
df = df[df['Tidspunkt_Faktisk_Avgang_Holdeplass_Fra'] < '24:00:00']
df = df[df['Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra'] < '24:00:00']
df = df[df['Tidspunkt_Planlagt_Avgang_Holdeplass_Fra'] < '24:00:00']

# %% [markdown]
# Konverterer tid

# %%
df['Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra'] = pd.to_timedelta(df['Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra'])
df['Tidspunkt_Faktisk_Avgang_Holdeplass_Fra'] = pd.to_timedelta(df['Tidspunkt_Faktisk_Avgang_Holdeplass_Fra'])
df['Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra'] = pd.to_timedelta(df['Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra'])
df['Tidspunkt_Planlagt_Avgang_Holdeplass_Fra'] = pd.to_timedelta(df['Tidspunkt_Planlagt_Avgang_Holdeplass_Fra'])

# %% [markdown]
# Konverterer dato

# %%
df['Dato'] = pd.to_datetime(df['Dato'], infer_datetime_format=True)

# %% [markdown]
# #### Feature 1: Beregne ankomst tidsforsinkelser

# %%
df['Ankomst_tidsforsinkelse'] = df['Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra'] - df['Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra']

# Checks if there is no delay
for index, row in df.iterrows():
    if(row['Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra'] < row['Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra']):
        df.loc[index, 'Ankomst_tidsforsinkelse'] = 0

# Convert to time
df['Ankomst_tidsforsinkelse'] = pd.to_timedelta(df['Ankomst_tidsforsinkelse'])
df.head()
# Out:
#                              TurId       Dato  Fylke Område Kommune  \
# 0  15006-2020-08-10T10:24:00+02:00 2020-10-08  Viken   Vest   Bærum
# 1  15002-2020-08-15T12:54:00+02:00 2020-08-15  Viken   Vest   Bærum
# 2  15004-2020-08-03T09:54:00+02:00 2020-03-08  Viken   Vest   Bærum
# 3  15003-2020-07-27T13:00:00+02:00 2020-07-27  Viken   Vest   Bærum
# 4  15002-2020-08-27T07:15:00+02:00 2020-08-27  Viken   Vest   Bærum
#
#                   Holdeplass_Fra                        Holdeplass_Til  \
# 0                    Nordliveien                             Tjernsmyr
# 1               Nadderud stadion  Bekkestua bussterminal (Plattform C)
# 2               Ringstabekkveien                               Skallum
# 3                      Gruvemyra                              Gullhaug
# 4  Lysaker stasjon (Plattform A)                             Tjernsmyr
#
#   Linjetype Linjefylke Linjenavn  Linjeretning  \
# 0     Lokal      Viken       150             0
# 1     Lokal      Viken       150             0
# 2     Lokal      Viken       150             0
# 3     Lokal      Viken       150             1
# 4     Lokal      Viken       150             1
#
#   Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# 0                          0 days 10:53:53
# 1                          0 days 13:12:20
# 2                          0 days 10:18:56
# 3                          0 days 13:52:04
# 4                          0 days 07:34:13
#
#   Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# 0                         0 days 10:53:59
# 1                         0 days 13:12:26
# 2                         0 days 10:19:21
# 3                         0 days 13:52:26
# 4                         0 days 07:34:53
#
#   Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# 0                           0 days 10:53:00
# 1                           0 days 13:12:00
# 2                           0 days 10:19:00
# 3                           0 days 13:51:00
# 4                           0 days 07:33:00
#
#   Tidspunkt_Planlagt_Avgang_Holdeplass_Fra  Kjøretøy_Kapasitet  \
# 0                          0 days 10:53:00                 112
# 1                          0 days 13:12:00                 112
# 2                          0 days 10:19:00                 112
# 3                          0 days 13:51:00                 112
# 4                          0 days 07:33:00                 112
#
#    Passasjerer_Ombord Ankomst_tidsforsinkelse
# 0                   5         0 days 00:00:53
# 1                   5         0 days 00:00:20
# 2                   6         0 days 00:00:00
# 3                  10         0 days 00:01:04
# 4                  10         0 days 00:01:13

# %% [markdown]
# #### Feature 2: Beregne avgang tidsforsinkelser

# %%
df['Avgang_tidsforsinkelse'] = df['Tidspunkt_Faktisk_Avgang_Holdeplass_Fra'] - df['Tidspunkt_Planlagt_Avgang_Holdeplass_Fra']

# Checks if there is no delay
for index, row in df.iterrows():
    if(row['Tidspunkt_Faktisk_Avgang_Holdeplass_Fra'] < row['Tidspunkt_Planlagt_Avgang_Holdeplass_Fra']):
        df.loc[index, 'Avgang_tidsforsinkelse'] = 0

# Convert to time
df['Avgang_tidsforsinkelse'] = pd.to_timedelta(df['Avgang_tidsforsinkelse'])
df.head()
# Out:
#                              TurId       Dato  Fylke Område Kommune  \
# 0  15006-2020-08-10T10:24:00+02:00 2020-10-08  Viken   Vest   Bærum
# 1  15002-2020-08-15T12:54:00+02:00 2020-08-15  Viken   Vest   Bærum
# 2  15004-2020-08-03T09:54:00+02:00 2020-03-08  Viken   Vest   Bærum
# 3  15003-2020-07-27T13:00:00+02:00 2020-07-27  Viken   Vest   Bærum
# 4  15002-2020-08-27T07:15:00+02:00 2020-08-27  Viken   Vest   Bærum
#
#                   Holdeplass_Fra                        Holdeplass_Til  \
# 0                    Nordliveien                             Tjernsmyr
# 1               Nadderud stadion  Bekkestua bussterminal (Plattform C)
# 2               Ringstabekkveien                               Skallum
# 3                      Gruvemyra                              Gullhaug
# 4  Lysaker stasjon (Plattform A)                             Tjernsmyr
#
#   Linjetype Linjefylke Linjenavn  Linjeretning  \
# 0     Lokal      Viken       150             0
# 1     Lokal      Viken       150             0
# 2     Lokal      Viken       150             0
# 3     Lokal      Viken       150             1
# 4     Lokal      Viken       150             1
#
#   Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# 0                          0 days 10:53:53
# 1                          0 days 13:12:20
# 2                          0 days 10:18:56
# 3                          0 days 13:52:04
# 4                          0 days 07:34:13
#
#   Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# 0                         0 days 10:53:59
# 1                         0 days 13:12:26
# 2                         0 days 10:19:21
# 3                         0 days 13:52:26
# 4                         0 days 07:34:53
#
#   Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# 0                           0 days 10:53:00
# 1                           0 days 13:12:00
# 2                           0 days 10:19:00
# 3                           0 days 13:51:00
# 4                           0 days 07:33:00
#
#   Tidspunkt_Planlagt_Avgang_Holdeplass_Fra  Kjøretøy_Kapasitet  \
# 0                          0 days 10:53:00                 112
# 1                          0 days 13:12:00                 112
# 2                          0 days 10:19:00                 112
# 3                          0 days 13:51:00                 112
# 4                          0 days 07:33:00                 112
#
#    Passasjerer_Ombord Ankomst_tidsforsinkelse Avgang_tidsforsinkelse
# 0                   5         0 days 00:00:53        0 days 00:00:59
# 1                   5         0 days 00:00:20        0 days 00:00:26
# 2                   6         0 days 00:00:00        0 days 00:00:21
# 3                  10         0 days 00:01:04        0 days 00:01:26
# 4                  10         0 days 00:01:13        0 days 00:01:53

# %% [markdown]
# #### Feature 3: Bool er forsinket

# %%
for index, row in df.iterrows():
    if(row['Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra'] < row['Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra']):
        df.loc[index, 'er_forsinket_Ankomst'] = False
    else:
        df.loc[index, 'er_forsinket_Ankomst'] = True
df.head()
# Out:
#                              TurId       Dato  Fylke Område Kommune  \
# 0  15006-2020-08-10T10:24:00+02:00 2020-10-08  Viken   Vest   Bærum
# 1  15002-2020-08-15T12:54:00+02:00 2020-08-15  Viken   Vest   Bærum
# 2  15004-2020-08-03T09:54:00+02:00 2020-03-08  Viken   Vest   Bærum
# 3  15003-2020-07-27T13:00:00+02:00 2020-07-27  Viken   Vest   Bærum
# 4  15002-2020-08-27T07:15:00+02:00 2020-08-27  Viken   Vest   Bærum
#
#                   Holdeplass_Fra                        Holdeplass_Til  \
# 0                    Nordliveien                             Tjernsmyr
# 1               Nadderud stadion  Bekkestua bussterminal (Plattform C)
# 2               Ringstabekkveien                               Skallum
# 3                      Gruvemyra                              Gullhaug
# 4  Lysaker stasjon (Plattform A)                             Tjernsmyr
#
#   Linjetype Linjefylke Linjenavn  Linjeretning  \
# 0     Lokal      Viken       150             0
# 1     Lokal      Viken       150             0
# 2     Lokal      Viken       150             0
# 3     Lokal      Viken       150             1
# 4     Lokal      Viken       150             1
#
#   Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
# 0                          0 days 10:53:53
# 1                          0 days 13:12:20
# 2                          0 days 10:18:56
# 3                          0 days 13:52:04
# 4                          0 days 07:34:13
#
#   Tidspunkt_Faktisk_Avgang_Holdeplass_Fra  \
# 0                         0 days 10:53:59
# 1                         0 days 13:12:26
# 2                         0 days 10:19:21
# 3                         0 days 13:52:26
# 4                         0 days 07:34:53
#
#   Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# 0                           0 days 10:53:00
# 1                           0 days 13:12:00
# 2                           0 days 10:19:00
# 3                           0 days 13:51:00
# 4                           0 days 07:33:00
#
#   Tidspunkt_Planlagt_Avgang_Holdeplass_Fra  Kjøretøy_Kapasitet  \
# 0                          0 days 10:53:00                 112
# 1                          0 days 13:12:00                 112
# 2                          0 days 10:19:00                 112
# 3                          0 days 13:51:00                 112
# 4                          0 days 07:33:00                 112
#
#    Passasjerer_Ombord Ankomst_tidsforsinkelse Avgang_tidsforsinkelse  \
# 0                   5         0 days 00:00:53        0 days 00:00:59
# 1                   5         0 days 00:00:20        0 days 00:00:26
# 2                   6         0 days 00:00:00        0 days 00:00:21
# 3                  10         0 days 00:01:04        0 days 00:01:26
# 4                  10         0 days 00:01:13        0 days 00:01:53
#
#   er_forsinket_Ankomst
# 0                 True
# 1                 True
# 2                False
# 3                 True
# 4                 True

# %% [markdown]
#  ### Checking for outliers and cleaning the data:

# %%
#Looking for outlaiers: (using a box plot)
df['Passasjerer_Ombord'].plot.box()

#The Negative values are outliers, and we need to remove them or replace them with resonable values (median). 
#Changing negativ values:
median_passasjerer_ombord = df['Passasjerer_Ombord'].median()
for index, row in df.iterrows():
    if row['Passasjerer_Ombord'] < 0:
        df.loc[index,'Passasjerer_Ombord'] =  median_passasjerer_ombord

# %%
df['Passasjerer_Ombord'].plot.box()
#checking if the max_value in this column is bigger than the biggest capacity: 
print("mest passasjerer_ombord", df['Passasjerer_Ombord'].max()) #no
print("størst kjøretøy",df['Kjøretøy_Kapasitet'].max())
print("minst kjøretøy",df['Kjøretøy_Kapasitet'].min())
df.head(15)
# Out:
# mest passasjerer_ombord 64
# størst kjøretøy 151
# minst kjøretøy 33
#                               TurId       Dato  Fylke    Område  \
# 0   15006-2020-08-10T10:24:00+02:00 2020-10-08  Viken      Vest
# 1   15002-2020-08-15T12:54:00+02:00 2020-08-15  Viken      Vest
# 2   15004-2020-08-03T09:54:00+02:00 2020-03-08  Viken      Vest
# 3   15003-2020-07-27T13:00:00+02:00 2020-07-27  Viken      Vest
# 4   15002-2020-08-27T07:15:00+02:00 2020-08-27  Viken      Vest
# 5    3110-2020-08-01T16:16:00+02:00 2020-01-08   Oslo   Nordøst
# 6   15010-2020-07-28T13:09:00+02:00 2020-07-28  Viken      Vest
# 7   15003-2020-07-27T06:18:00+02:00 2020-07-27   Oslo  Indre By
# 8   21002-2020-08-16T14:33:00+02:00 2020-08-16  Viken      Vest
# 9   15002-2020-08-13T18:09:00+02:00 2020-08-13  Viken      Vest
# 10  49005-2020-06-23T21:30:00+02:00 2020-06-23  Viken       Sør
# 11  21005-2020-08-17T17:55:00+02:00 2020-08-17  Viken      Vest
# 13  15001-2020-08-06T17:00:00+02:00 2020-06-08  Viken      Vest
# 14  15005-2020-07-17T18:00:00+02:00 2020-07-17  Viken      Vest
# 15  15003-2020-08-08T19:18:00+02:00 2020-08-08  Viken      Vest
#
#           Kommune                               Holdeplass_Fra  \
# 0           Bærum                                  Nordliveien
# 1           Bærum                             Nadderud stadion
# 2           Bærum                             Ringstabekkveien
# 3           Bærum                                    Gruvemyra
# 4           Bærum                Lysaker stasjon (Plattform A)
# 5          Bjerke                     Veitvet  (mot Kalbakken)
# 6           Bærum                             Nedre Toppenhaug
# 7   St.Hanshaugen  Hammersborggata (ved Storgata retning vest)
# 8           Bærum                                   Stein gård
# 9           Bærum         Bekkestua bussterminal (Plattform C)
# 10  Indre Østfold                                        Fjell
# 11          Bærum                                 Haslum skole
# 13          Bærum                             Ringstabekkveien
# 14          Bærum                             Nadderud stadion
# 15          Bærum                                Guldbrandslia
#
#                            Holdeplass_Til Linjetype Linjefylke Linjenavn  \
# 0                               Tjernsmyr     Lokal      Viken       150
# 1    Bekkestua bussterminal (Plattform C)     Lokal      Viken       150
# 2                                 Skallum     Lokal      Viken       150
# 3                                Gullhaug     Lokal      Viken       150
# 4                               Tjernsmyr     Lokal      Viken       150
# 5                Rødtvet  (mot Kalbakken)     Lokal       Oslo        31
# 5                    8         0 days 00:06:56        0 days 00:07:23
# 6                    1         0 days 00:02:00        0 days 00:02:05
# 7                    3         0 days 00:00:24        0 days 00:00:29
# 8                    2         0 days 00:01:12        0 days 00:01:34
# 9                    4         0 days 00:08:41        0 days 00:09:19
# 10                   1         0 days 00:05:07        0 days 00:05:09
# 11                   3         0 days 00:06:31        0 days 00:06:56
# 13                  10         0 days 00:09:07        0 days 00:09:29
# 14                   9         0 days 00:00:40        0 days 00:00:45
# 15                   3         0 days 00:02:55        0 days 00:03:01
#
#    er_forsinket_Ankomst
# 0                  True
# 1                  True
# 2                 False
# 3                  True
# 4                  True
# 5                  True
# 6                  True
# 7                  True
# 8                  True
# 9                  True
# 10                 True
# 11                 True
# 13                 True
# 14                 True
# 15                 True

# %% [markdown]
# #### Feature 4: Ledige plasser

# %%
df['Ledige_Plasser'] = df['Kjøretøy_Kapasitet'] - df['Passasjerer_Ombord']
df.head(10)
# Out:
#                              TurId       Dato  Fylke    Område        Kommune  \
# 0  15006-2020-08-10T10:24:00+02:00 2020-10-08  Viken      Vest          Bærum
# 1  15002-2020-08-15T12:54:00+02:00 2020-08-15  Viken      Vest          Bærum
# 2  15004-2020-08-03T09:54:00+02:00 2020-03-08  Viken      Vest          Bærum
# 3  15003-2020-07-27T13:00:00+02:00 2020-07-27  Viken      Vest          Bærum
# 4  15002-2020-08-27T07:15:00+02:00 2020-08-27  Viken      Vest          Bærum
# 5   3110-2020-08-01T16:16:00+02:00 2020-01-08   Oslo   Nordøst         Bjerke
# 6  15010-2020-07-28T13:09:00+02:00 2020-07-28  Viken      Vest          Bærum
# 7  15003-2020-07-27T06:18:00+02:00 2020-07-27   Oslo  Indre By  St.Hanshaugen
# 8  21002-2020-08-16T14:33:00+02:00 2020-08-16  Viken      Vest          Bærum
# 9  15002-2020-08-13T18:09:00+02:00 2020-08-13  Viken      Vest          Bærum
#
#                                 Holdeplass_Fra  \
# 0                                  Nordliveien
# 1                             Nadderud stadion
# 2                             Ringstabekkveien
# 3                                    Gruvemyra
# 4                Lysaker stasjon (Plattform A)
# 5                     Veitvet  (mot Kalbakken)
# 6                             Nedre Toppenhaug
# 7  Hammersborggata (ved Storgata retning vest)
# 8                                   Stein gård
# 9         Bekkestua bussterminal (Plattform C)
#
#                           Holdeplass_Til Linjetype Linjefylke Linjenavn  ...  \
# 0                              Tjernsmyr     Lokal      Viken       150  ...
# 1   Bekkestua bussterminal (Plattform C)     Lokal      Viken       150  ...
# 2                                Skallum     Lokal      Viken       150  ...
# 3                               Gullhaug     Lokal      Viken       150  ...
# 4                              Tjernsmyr     Lokal      Viken       150  ...
# 5               Rødtvet  (mot Kalbakken)     Lokal       Oslo        31  ...
# 6                        Øvre Toppenhaug     Lokal      Viken       150  ...
# 7  St. Olavs plass  (mot Frederiks gate)     Lokal      Viken       150  ...
# 8                         Knabberudveien     Lokal      Viken       150  ...
# 9                          Stabekk skole     Lokal      Viken       150  ...
#
#    Tidspunkt_Faktisk_Ankomst_Holdeplass_Fra  \
#plt.plot(x,y)
plt.bar(x,y,alpha=1, width=0.8)
plt.title("Antall passasjerer per Linjenavn")
plt.xlabel("Linjenavn")
plt.ylabel("Passasjerer_Ombord")
plt.xticks(x, y, rotation=90)
plt.tick_params(axis='x', which='major', labelsize=5)
#plt.tight_layout()

# %% [markdown]
# #### Plot 2: Antall passasjerer per kommune

# %%
antall_passasjerer_per_kommune = df.groupby('Kommune', as_index=False).agg({'Passasjerer_Ombord':'sum'})
antall_passasjerer_per_kommune.plot.bar(x='Kommune',ylabel='Passasjerer Ombord', title="Antall passasjerer per Kommune")
# antall_passasjerer_per_kommune
# Out:
# <AxesSubplot:title={'center':'Antall passasjerer per Kommune'}, xlabel='Kommune', ylabel='Passasjerer Ombord'>

# %% [markdown]
# #### Ny kolonne: Tidsperiode

# %%
# df = df[df['Tidspunkt_Faktisk_Avgang_Holdeplass_Fra'] > pd.to_timedelta(0)]
tid = df["Tidspunkt_Faktisk_Avgang_Holdeplass_Fra"]
conditions = [
    (tid >= pd.Timedelta(hours=5)) & (tid < pd.Timedelta(hours=13)),
    (tid >= pd.Timedelta(hours=13)) & (tid < pd.Timedelta(hours=18)),
    (tid >= pd.Timedelta(hours=18)) & (tid < pd.Timedelta(hours=22)),
    (tid >= pd.Timedelta(hours=22)) | (tid < pd.Timedelta(hours=5))
]
values = ["Morgen", "Ettermiddag", "Kveld","Natt"]
df['Tidsperiode'] = np.select(conditions, values)
df.head()
# Out:
#                              TurId       Dato  Fylke Område Kommune  \
# 0  15006-2020-08-10T10:24:00+02:00 2020-10-08  Viken   Vest   Bærum
# 1  15002-2020-08-15T12:54:00+02:00 2020-08-15  Viken   Vest   Bærum
# 2  15004-2020-08-03T09:54:00+02:00 2020-03-08  Viken   Vest   Bærum
# 3  15003-2020-07-27T13:00:00+02:00 2020-07-27  Viken   Vest   Bærum
# 4  15002-2020-08-27T07:15:00+02:00 2020-08-27  Viken   Vest   Bærum
#
#                   Holdeplass_Fra                        Holdeplass_Til  \
# 0                    Nordliveien                             Tjernsmyr
# 1               Nadderud stadion  Bekkestua bussterminal (Plattform C)
# 2               Ringstabekkveien                               Skallum
# 3                      Gruvemyra                              Gullhaug
# 4  Lysaker stasjon (Plattform A)                             Tjernsmyr
#
#   Linjetype Linjefylke Linjenavn  ...  \
# 0     Lokal      Viken       150  ...
# 1     Lokal      Viken       150  ...
# 2     Lokal      Viken       150  ...
# 3     Lokal      Viken       150  ...
# 4     Lokal      Viken       150  ...
#
#    Tidspunkt_Planlagt_Ankomst_Holdeplass_Fra  \
# 0                            0 days 10:53:00
# 1                            0 days 13:12:00
# 2                            0 days 10:19:00
# 3                            0 days 13:51:00
# 4                            0 days 07:33:00
#
#   Tidspunkt_Planlagt_Avgang_Holdeplass_Fra Kjøretøy_Kapasitet  \
# 0                          0 days 10:53:00                112
# 1                          0 days 13:12:00                112
# 2                          0 days 10:19:00                112
# 3                          0 days 13:51:00                112
# 4                          0 days 07:33:00                112
#
#   Passasjerer_Ombord Ankomst_tidsforsinkelse  Avgang_tidsforsinkelse  \
# 0                  5         0 days 00:00:53         0 days 00:00:59
# 1                  5         0 days 00:00:20         0 days 00:00:26
# 2                  6         0 days 00:00:00         0 days 00:00:21
# 3                 10         0 days 00:01:04         0 days 00:01:26
# 4                 10         0 days 00:01:13         0 days 00:01:53
#
#    er_forsinket_Ankomst Ledige_Plasser Travelt_Nivå  Tidsperiode
# 0                  True            107    God plass       Morgen
# 1                  True            107    God plass  Ettermiddag
# 2                 False            106        Medum       Morgen
# 3                  True            102        Medum  Ettermiddag
# 4                  True            102        Medum       Morgen
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Plot 3: Antall pasasajerer per tidsperiode
# Viser hvor mange passasjerer ombord i hvilken tidsperiode

# %%
antall_passasjerer_per_tidsperiode = df.groupby('Tidsperiode', as_index=False).agg({'Passasjerer_Ombord':'sum'})
antall_passasjerer_per_tidsperiode.plot.bar(rot=45, x='Tidsperiode',ylabel='Passasjerer Ombord', title="Antall passasjerer per Tidsperiode")
antall_passasjerer_per_tidsperiode
# Out:
#    Tidsperiode  Passasjerer_Ombord
# 0  Ettermiddag               11862
# 1        Kveld                6200
# 2       Morgen               11264
# 3         Natt                1728

# %% [markdown]
# #### Plot 4: Antall forsinket busser per tidsperiode
# Viser hvor mange busser er forsinket i hvilken tidsperiode

# %%
forsinket_ankomst_per_tidsperiode = df.groupby('Tidsperiode', as_index=False).agg({'er_forsinket_Ankomst':'sum'})
forsinket_ankomst_per_tidsperiode.plot.bar(rot=45, x='Tidsperiode', ylabel='Antall forsinket busser', title='Antall forsinket (ankomst) busser per Tidsperiode') 
forsinket_ankomst_per_tidsperiode
# Out:
#    Tidsperiode  er_forsinket_Ankomst
# 0  Ettermiddag                  1650
# 1        Kveld                   905
# 2       Morgen                  2050
# 3         Natt                   370

# %% [markdown]
# Viser hvor mange busser er forsinket i hvilken tidsperiode og den totale antall busser per tidsperiode på samme plot

# %%
antall_busser_per_periode = df['Linjenavn'].groupby(df['Tidsperiode']).count()
forsinket_ankomst_per_tidsperiode = df.groupby('Tidsperiode', as_index=False).agg({'er_forsinket_Ankomst':'sum'})

data = {
    'tidsperiode': forsinket_ankomst_per_tidsperiode['Tidsperiode'].array,
    'antall_busser': antall_busser_per_periode.array, 
    'antall_forsinket_busser': forsinket_ankomst_per_tidsperiode['er_forsinket_Ankomst'].array,
    }
df_plot_4 = pd.DataFrame(data=data)
df_plot_4.plot.bar(x='tidsperiode', ylabel="antall busser", rot=45)
df_plot_4
# Out:
#    tidsperiode  antall_busser  antall_forsinket_busser
# 0  Ettermiddag           1863                     1650
# 1        Kveld           1046                      905
# 2       Morgen           2439                     2050
# 3         Natt            426                      370

# %% [markdown]
# #### Plot 5: Antall travelt busser per tidsperiode
# Viser:
# - hvor mange busser er forsinket i hvilken tidsperiode,
# - den totale antall busser per tidsperiode
# - antall busser med lite plass per tidsperiode
#
# ...på samme plot.

# %%
tmp = df[df['Travelt_Nivå'].isin(['Lite plass'])]
tmp = tmp.groupby('Tidsperiode').count()
df_plot_4['antall_travelt_busser'] = tmp['Travelt_Nivå'].array # busser med lite plass
df_plot_4.plot.bar(x='tidsperiode', ylabel="antall busser", rot=45)
df_plot_4.plot.line(x='tidsperiode', ylabel="antall busser", rot=45)
df_plot_4
# Out:
#    tidsperiode  antall_busser  antall_forsinket_busser  antall_travelt_busser
# 0  Ettermiddag           1863                     1650                    708
# 1        Kveld           1046                      905                    357
# 2       Morgen           2439                     2050                    801
# 3         Natt            426                      370                     96

# %% [markdown]
# #### Plot 6: forsinkelse per kommune

# %%
#Plotet skal vise hvilken Kommune har mest forsinkelse.

forsinket_ankomst_per_kommune = df.groupby('Kommune', as_index=False).agg({'er_forsinket_Ankomst':'sum'})
forsinket_ankomst_per_kommune.plot.bar(rot=90, x='Kommune', ylabel='Antall forsinket busser', title='Antall forsinket (ankomst) busser per Kommune')
# Out:
# <AxesSubplot:title={'center':'Antall forsinket (ankomst) busser per Kommune'}, xlabel='Kommune', ylabel='Antall forsinket busser'>

# %% [markdown]
# #### Dateframe: per month

# %%
# Verdier
måned = df['Dato'].dt.month
antall_busser = df['Linjenavn'].groupby(måned).count()
antall_forsinket_busser = df.groupby(måned, as_index=False).agg({'er_forsinket_Ankomst':'sum'})
antall_passasjerer = df.groupby(måned, as_index=False).agg({'Passasjerer_Ombord':'sum'})
m = ["Jan", "Feb", "Mar", "Apr", "Mai", "Jun", "Jul", "Aug", "Sep", "Okt", "Nov", "Des"]

data = {
    'måned': måned,
    'antall_busser':df['Linjenavn'],
}

df_plot_7 = pd.DataFrame(data=data)
df_plot_7 = df_plot_7.groupby('måned')
df_plot_7 = df_plot_7.count()
df_plot_7['antall_forsinket_busser'] = antall_forsinket_busser['er_forsinket_Ankomst'].array
df_plot_7['antall_passasjerer'] = antall_passasjerer['Passasjerer_Ombord'].array
df_plot_7['måned_navn'] = m

df_plot_7
# Out:
#        antall_busser  antall_forsinket_busser  antall_passasjerer måned_navn
# måned
# 1                152                      122                 810        Jan
# 2                175                      154                 871        Feb
# 3                228                      204                1144        Mar
# 4                169                      149                 856        Apr
# 5                184                      162                 934        Mai
# 6               1044                      894                5913        Jun
# 7               1503                     1254                7317        Jul
# 8               1615                     1418                9187        Aug
# 9                168                      150                 951        Sep
# 10               188                      160                 992        Okt
# 11               175                      155                1137        Nov
# 12               173                      153                 942        Des

# %% [markdown]
# #### Plot 7.1: Antall passasjerer per måned

# %%
df_plot_7.plot.bar(x='måned_navn', y='antall_passasjerer', rot=0)
df_plot_7['antall_passasjerer']
# Out:
# måned
# 1      810
# 2      871
# 3     1144
# 4      856
# 5      934
# 6     5913
# 7     7317
# 8     9187
# 9      951
# 10     992
# 11    1137
# 12     942
# Name: antall_passasjerer, dtype: int64

# %% [markdown]
# #### Plot 7.2: Antall forsinket busser per måned

# %%
df_plot_7.plot.bar(x='måned_navn', y=['antall_forsinket_busser'], rot=0)
df_plot_7['antall_forsinket_busser']
# Out:
# måned
# 1      122
# 2      154
# 3      204
# 4      149
# 5      162
# 6      894
# 7     1254
# 8     1418
# 9      150
# 10     160
# 11     155
# 12     153
# Name: antall_forsinket_busser, dtype: int64
